# %%
# =======================
# 1. Imports
# =======================
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# ===================================
# 2. Load datasets (train + eval)
# ====================================
train_df = pd.read_csv(r'C:\Users\sheri\Desktop\machinlearning\data\processed_data\feature_engineered_train.csv')
eval_df = pd.read_csv(r'C:\Users\sheri\Desktop\machinlearning\data\processed_data\featured_engineered_eval.csv')

# %%
# ===========================================================
# 3. Drop high VIF features if any (both train + eval)
# ===========================================================

# No features drop since there are no one with high VIF

# %%
# =============================
# 4. Define target & features
# ==============================
target = "AEP_MW"
X_train = train_df.drop(columns=[target])
y_train = train_df[target]

X_eval = eval_df.drop(columns=[target])
y_eval = eval_df[target]

# %%
# ===========================================================
# 5. Standardization (fit on train, gtransform eval)
# ===========================================================
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_eval_scaled = scaler.transform(X_eval)

# %%
# ===============================
# 6. Train & Evaliate Models
# ================================

# ---- Linear Regression -----
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
y_pred_lr = lr.predict(X_eval_scaled)

print("Linear Regression:")
print(" MAE:", mean_absolute_error(y_eval, y_pred_lr))
print(" RMSE:", np.sqrt(mean_absolute_error(y_eval, y_pred_lr)))
print(" R2:", r2_score(y_eval, y_pred_lr))
# Out:
# Linear Regression:
#  MAE: 1897.8834634388918
#  RMSE: 43.564704330901776
#  R2: 0.1374104225087206

# %%
# ---- Ridge Regression ----
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, y_train)
y_pred_ridge = ridge.predict(X_eval_scaled)

print("\nRidge Regression:")
print(" MAE:", mean_absolute_error(y_eval, y_pred_ridge))
print(" RMSE:", np.sqrt(mean_absolute_error(y_eval, y_pred_ridge)))
print(" R2:", r2_score(y_eval, y_pred_ridge))
# Out:
# Ridge Regression:
#  MAE: 1897.884665378029
#  RMSE: 43.56471812577271
#  R2: 0.13740981810912256

# %%
# ---- Lasso Regression ----
lasso = Lasso(alpha=0.1)
lasso.fit(X_train_scaled, y_train)
y_pred_lasso = lasso.predict(X_eval_scaled)

print("\nLasso Regression")
print(" MAE:", mean_absolute_error(y_eval, y_pred_lasso))
print(" RMSE:", np.sqrt(mean_absolute_error(y_eval, y_pred_lasso)))
print(" R2:", r2_score(y_eval, y_pred_lasso))
# Out:
# Lasso Regression
#  MAE: 1897.9835301195653
#  RMSE: 43.56585279917708
#  R2: 0.13733500601552284
